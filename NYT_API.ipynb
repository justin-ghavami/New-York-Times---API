# %% [markdown]
# ## Imports

# %%
import requests 
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# ## Query The Data Through The NYT API. 🗞

# %%
def execute(year, month):
  requestUrl = f"https://api.nytimes.com/svc/archive/v1/{year}/{month}.json?api-key=wzF4H7JVaVYRQ6h74L0lszlGtxzFMKK5"
  requestHeaders = {
    "Accept": "application/json"
  }

  response = requests.get(requestUrl, headers=requestHeaders)

  return response

if __name__ == "__main__":
  execute(2022, 6)

# %% [markdown]
# ## Checking Our Response

# %%
response = execute(2022, 6)
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ## Bringing the data into a DataFrame

# %% [markdown]
# **I have no systematic way of bringing my data into a Pandas DataFrame. I typically just go through the data & explore it as much as I can to understand it and then bring it into a DataFrame.**

# %%
json_response = response.json()
for i in json_response['response']['docs'][:5]:
  print(i)
# Out:
# {'abstract': 'A senior administration official said the rocket system was provided only after direct assurances by Ukraine’s leaders that they would not use it against targets in Russian territory.', 'web_url': 'https://www.nytimes.com/2022/05/31/us/politics/biden-ukraine-rockets.html', 'snippet': 'A senior administration official said the rocket system was provided only after direct assurances by Ukraine’s leaders that they would not use it against targets in Russian territory.', 'lead_paragraph': 'WASHINGTON — The United States will send Ukraine advanced rocket systems and munitions as part of a new $700 million package of military equipment intended to help the Ukrainians fight back against the Russian invasion of their country, President Biden and White House officials said on Tuesday.', 'print_section': 'A', 'print_page': '9', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31dc-biden4/31dc-biden4-articleLarge.jpg', 'height': 400, 'width': 600, 'subType': 'xlarge', 'crop_name': 'articleLarge', 'legacy': {'xlarge': 'images/2022/05/31/multimedia/31dc-biden4/31dc-biden4-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31dc-biden4/31dc-biden4-jumbo.jpg', 'height': 683, 'width': 1024, 'subType': 'jumbo', 'crop_name': 'jumbo', 'legacy': {}}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31dc-biden4/31dc-biden4-superJumbo.jpg', 'height': 1366, 'width': 2048, 'subType': 'superJumbo', 'crop_name': 'superJumbo', 'legacy': {}}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31dc-biden4/31dc-biden4-thumbStandard.jpg', 'height': 75, 'width': 75, 'subType': 'thumbnail', 'crop_name': 'thumbStandard', 'legacy': {'thumbnail': 'images/2022/05/31/multimedia/31dc-biden4/31dc-biden4-thumbStandard.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}}, {'rank': 0, 'subtype': 'thumbLarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31dc-biden4/31dc-biden4-thumbLarge.jpg', 'height': 150, 'width': 150, 'subType': 'thumbLarge', 'crop_name': 'thumbLarge', 'legacy': {}}], 'headline': {'main': 'U.S. to Send Ukraine $700 Million in Military Aid, Including Advanced Rockets', 'kicker': None, 'content_kicker': None, 'print_headline': 'New Rockets In $700 Million  Of Military Aid', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'persons', 'value': 'Biden, Joseph R Jr', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Russian Invasion of Ukraine (2022)', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'United States Politics and Government', 'rank': 3, 'major': 'N'}, {'name': 'organizations', 'value': 'Defense Department', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Putin, Vladimir V', 'rank': 5, 'major': 'N'}, {'name': 'glocations', 'value': 'Ukraine', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Russia', 'rank': 7, 'major': 'N'}, {'name': 'subject', 'value': 'Defense and Military Forces', 'rank': 8, 'major': 'N'}], 'pub_date': '2022-06-01T00:05:37+0000', 'document_type': 'article', 'news_desk': 'Washington', 'section_name': 'U.S.', 'subsection_name': 'Politics', 'byline': {'original': 'By Michael D. Shear', 'person': [{'firstname': 'Michael', 'middlename': None, 'lastname': '', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'type_of_material': 'News', '_id': 'nyt://article/09f1e20a-5d5b-5908-875b-830f45c71bf0', 'word_count': 964, 'uri': 'nyt://article/09f1e20a-5d5b-5908-875b-830f45c71bf0'}
# {'abstract': 'The 47-year-old man frequently swam into a lake near a disc golf course to retrieve stray discs and sell them, a park official said.', 'web_url': 'https://www.nytimes.com/2022/05/31/us/alligator-kills-florida-man-retrieving-frisbees-in-lake-officials-say.html', 'snippet': 'The 47-year-old man frequently swam into a lake near a disc golf course to retrieve stray discs and sell them, a park official said.', 'lead_paragraph': 'The body of a man who had been retrieving Frisbees from a Florida public park’s lake that serves as habitat for alligators was found with its arm torn off on Tuesday, the authorities said. It was the state’s first fatal alligator attack since 2019.', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31xp-gator-1/31xp-gator-1-articleLarge-v2.jpg', 'height': 400, 'width': 600, 'subType': 'xlarge', 'crop_name': 'articleLarge', 'legacy': {'xlarge': 'images/2022/05/31/multimedia/31xp-gator-1/31xp-gator-1-articleLarge-v2.jpg', 'xlargewidth': 600, 'xlargeheight': 400}}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31xp-gator-1/31xp-gator-1-jumbo-v2.jpg', 'height': 683, 'width': 1024, 'subType': 'jumbo', 'crop_name': 'jumbo', 'legacy': {}}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31xp-gator-1/31xp-gator-1-superJumbo-v2.jpg', 'height': 1366, 'width': 2048, 'subType': 'superJumbo', 'crop_name': 'superJumbo', 'legacy': {}}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31xp-gator-1/31xp-gator-1-thumbStandard.jpg', 'height': 75, 'width': 75, 'subType': 'thumbnail', 'crop_name': 'thumbStandard', 'legacy': {'thumbnail': 'images/2022/05/31/multimedia/31xp-gator-1/31xp-gator-1-thumbStandard.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}}, {'rank': 0, 'subtype': 'thumbLarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31xp-gator-1/31xp-gator-1-thumbLarge.jpg', 'height': 150, 'width': 150, 'subType': 'thumbLarge', 'crop_name': 'thumbLarge', 'legacy': {}}], 'headline': {'main': 'Alligator Kills Florida Man Retrieving Frisbees in Lake, Officials Say', 'kicker': None, 'content_kicker': None, 'print_headline': '', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Alligators', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Frisbees', 'rank': 2, 'major': 'N'}, {'name': 'subject', 'value': 'Deaths (Fatalities)', 'rank': 3, 'major': 'N'}, {'name': 'subject', 'value': 'Parks and Other Recreation Areas', 'rank': 4, 'major': 'N'}, {'name': 'glocations', 'value': 'Largo (Fla)', 'rank': 5, 'major': 'N'}, {'name': 'glocations', 'value': 'Pinellas County (Fla)', 'rank': 6, 'major': 'N'}, {'name': 'glocations', 'value': 'Florida', 'rank': 7, 'major': 'N'}], 'pub_date': '2022-06-01T00:42:23+0000', 'document_type': 'article', 'news_desk': 'Express', 'section_name': 'U.S.', 'byline': {'original': 'By Alex Traub', 'person': [{'firstname': 'Alex', 'middlename': None, 'lastname': 'Traub', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'type_of_material': 'News', '_id': 'nyt://article/7e2ae77b-4d75-5b1b-9773-51f37d7551af', 'word_count': 683, 'uri': 'nyt://article/7e2ae77b-4d75-5b1b-9773-51f37d7551af'}
# {'abstract': 'Corrections that appeared in print on Wednesday, June 1, 2022.', 'web_url': 'https://www.nytimes.com/2022/05/31/pageoneplus/corrections-june-1-2022.html', 'snippet': 'Corrections that appeared in print on Wednesday, June 1, 2022.', 'lead_paragraph': 'An article on Tuesday about a draft of an agreement by the European Union to ban most Russian oil imports misstated the E.U.’s previous actions against Russia for the invasion of Ukraine. It has not barred imports of Russian natural gas, but individual nations have.', 'print_section': 'A', 'print_page': '21', 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'Corrections: June 1, 2022', 'kicker': None, 'content_kicker': None, 'print_headline': 'Corrections', 'name': None, 'seo': None, 'sub': None}, 'keywords': [], 'pub_date': '2022-06-01T00:54:49+0000', 'document_type': 'article', 'news_desk': 'Corrections', 'section_name': 'Corrections', 'byline': {'original': '', 'person': [], 'organization': None}, 'type_of_material': 'Correction', '_id': 'nyt://article/0b55b248-0bfe-503d-8bcc-18f5d33a7589', 'word_count': 440, 'uri': 'nyt://article/0b55b248-0bfe-503d-8bcc-18f5d33a7589'}
# {'abstract': 'Quotation of the Day for Wednesday, June 1, 2022.', 'web_url': 'https://www.nytimes.com/2022/05/31/todayspaper/quotation-of-the-day-allinllachu-world-quechua-joins-google-translate.html', 'snippet': 'Quotation of the Day for Wednesday, June 1, 2022.', 'lead_paragraph': '“It’s like saying to the world, ‘look, here we are!’”', 'print_section': 'A', 'print_page': '3', 'source': 'The New York Times', 'multimedia': [], 'headline': {'main': 'Quotation of the Day: Allinllachu, World: Quechua Joins Google Translate', 'kicker': None, 'content_kicker': None, 'print_headline': 'Quote of the Day', 'name': None, 'seo': None, 'sub': None}, 'keywords': [], 'pub_date': '2022-06-01T00:55:52+0000', 'document_type': 'article', 'news_desk': 'Summary', 'section_name': 'Today’s Paper', 'byline': {'original': '', 'person': [], 'organization': None}, 'type_of_material': 'Quote', '_id': 'nyt://article/bccb0fd1-5bbe-5889-a2f6-363851738dc9', 'word_count': 30, 'uri': 'nyt://article/bccb0fd1-5bbe-5889-a2f6-363851738dc9'}
# {'abstract': 'A judge ruled that Ms. Palin failed to introduce “even a speck” of evidence to prove the newspaper defamed her in a 2017 editorial that mistakenly connected her political rhetoric with a mass shooting.', 'web_url': 'https://www.nytimes.com/2022/05/31/business/sarah-palin-new-york-times-libel.html', 'snippet': 'A judge ruled that Ms. Palin failed to introduce “even a speck” of evidence to prove the newspaper defamed her in a 2017 editorial that mistakenly connected her political rhetoric with a mass shooting.', 'lead_paragraph': 'Sarah Palin lost her bid for a new trial in her libel case against The New York Times on Tuesday, with a judge ruling that she had failed to introduce “even a speck” of evidence necessary to prove the newspaper had defamed her in a 2017 editorial.', 'print_section': 'B', 'print_page': '4', 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31palin-nyt-1/31palin-nyt-1-articleLarge.jpg', 'height': 400, 'width': 600, 'subType': 'xlarge', 'crop_name': 'articleLarge', 'legacy': {'xlarge': 'images/2022/05/31/multimedia/31palin-nyt-1/31palin-nyt-1-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 400}}, {'rank': 0, 'subtype': 'jumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31palin-nyt-1/31palin-nyt-1-jumbo.jpg', 'height': 682, 'width': 1024, 'subType': 'jumbo', 'crop_name': 'jumbo', 'legacy': {}}, {'rank': 0, 'subtype': 'superJumbo', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31palin-nyt-1/31palin-nyt-1-superJumbo.jpg', 'height': 1365, 'width': 2048, 'subType': 'superJumbo', 'crop_name': 'superJumbo', 'legacy': {}}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31palin-nyt-1/31palin-nyt-1-thumbStandard.jpg', 'height': 75, 'width': 75, 'subType': 'thumbnail', 'crop_name': 'thumbStandard', 'legacy': {'thumbnail': 'images/2022/05/31/multimedia/31palin-nyt-1/31palin-nyt-1-thumbStandard.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}}, {'rank': 0, 'subtype': 'thumbLarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2022/05/31/multimedia/31palin-nyt-1/31palin-nyt-1-thumbLarge.jpg', 'height': 150, 'width': 150, 'subType': 'thumbLarge', 'crop_name': 'thumbLarge', 'legacy': {}}], 'headline': {'main': 'Sarah Palin’s Bid for New Libel Trial Against The Times Is Denied', 'kicker': None, 'content_kicker': None, 'print_headline': 'Citing Lack of Evidence, Judge Rejects Palin’s Bid for New Trial Against Times', 'name': None, 'seo': None, 'sub': None}, 'keywords': [{'name': 'subject', 'value': 'Libel and Slander', 'rank': 1, 'major': 'N'}, {'name': 'subject', 'value': 'Suits and Litigation (Civil)', 'rank': 2, 'major': 'N'}, {'name': 'organizations', 'value': 'New York Times', 'rank': 3, 'major': 'N'}, {'name': 'persons', 'value': 'Palin, Sarah', 'rank': 4, 'major': 'N'}, {'name': 'persons', 'value': 'Rakoff, Jed S', 'rank': 5, 'major': 'N'}, {'name': 'subject', 'value': 'Newspapers', 'rank': 6, 'major': 'N'}], 'pub_date': '2022-06-01T01:14:09+0000', 'document_type': 'article', 'news_desk': 'Business', 'section_name': 'Business Day', 'byline': {'original': 'By Sheera Frenkel', 'person': [{'firstname': 'Sheera', 'middlename': None, 'lastname': 'Frenkel', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'type_of_material': 'News', '_id': 'nyt://article/a82cb17f-3a34-544d-8f6d-66351480bc43', 'word_count': 534, 'uri': 'nyt://article/a82cb17f-3a34-544d-8f6d-66351480bc43'}

# %%
df = pd.DataFrame.from_dict(json_response['response']['docs'])
df.head()
# Out:
#                                             abstract  \
# 0  A senior administration official said the rock...
# 1  The 47-year-old man frequently swam into a lak...
# 2  Corrections that appeared in print on Wednesda...
# 3  Quotation of the Day for Wednesday, June 1, 2022.
# 4  A judge ruled that Ms. Palin failed to introdu...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2022/05/31/us/politics...
# 1  https://www.nytimes.com/2022/05/31/us/alligato...
# 2  https://www.nytimes.com/2022/05/31/pageoneplus...
# 3  https://www.nytimes.com/2022/05/31/todayspaper...
# 4  https://www.nytimes.com/2022/05/31/business/sa...
#
#                                              snippet  \
# 0  A senior administration official said the rock...
# 1  The 47-year-old man frequently swam into a lak...
# 2  Corrections that appeared in print on Wednesda...
# 3  Quotation of the Day for Wednesday, June 1, 2022.
# 4  A judge ruled that Ms. Palin failed to introdu...
#
#                                       lead_paragraph print_section print_page  \
# 0  WASHINGTON — The United States will send Ukrai...             A          9
# 1  The body of a man who had been retrieving Fris...           NaN        NaN
# 2  An article on Tuesday about a draft of an agre...             A         21
# 3  “It’s like saying to the world, ‘look, here we...             A          3
# 4  Sarah Palin lost her bid for a new trial in he...             B          4
#
#                source                                         multimedia  \
# 0  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 1  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
# 2  The New York Times                                                 []
# 3  The New York Times                                                 []
# 4  The New York Times  [{'rank': 0, 'subtype': 'xlarge', 'caption': N...
#
#                                             headline  \
# 0  {'main': 'U.S. to Send Ukraine $700 Million in...
# 1  {'main': 'Alligator Kills Florida Man Retrievi...
# 2  {'main': 'Corrections: June 1, 2022', 'kicker'...
# 3  {'main': 'Quotation of the Day: Allinllachu, W...
# 4  {'main': 'Sarah Palin’s Bid for New Libel Tria...
#
#                                             keywords  \
# 0  [{'name': 'persons', 'value': 'Biden, Joseph R...
# 1  [{'name': 'subject', 'value': 'Alligators', 'r...
# 2                                                 []
# 3                                                 []
# 4  [{'name': 'subject', 'value': 'Libel and Sland...
#
#                    pub_date document_type    news_desk   section_name  \
# 0  2022-06-01T00:05:37+0000       article   Washington           U.S.
# 1  2022-06-01T00:42:23+0000       article      Express           U.S.
# 2  2022-06-01T00:54:49+0000       article  Corrections    Corrections
# 3  2022-06-01T00:55:52+0000       article      Summary  Today’s Paper
# 4  2022-06-01T01:14:09+0000       article     Business   Business Day
#
#   subsection_name                                             byline  \
# 0        Politics  {'original': 'By Michael D. Shear', 'person': ...
# 1             NaN  {'original': 'By Alex Traub', 'person': [{'fir...
# 2             NaN  {'original': '', 'person': [], 'organization':...
# 3             NaN  {'original': '', 'person': [], 'organization':...
# 4             NaN  {'original': 'By Sheera Frenkel', 'person': [{...
#
#   type_of_material                                                _id  \
# 0             News  nyt://article/09f1e20a-5d5b-5908-875b-830f45c7...
# 1             News  nyt://article/7e2ae77b-4d75-5b1b-9773-51f37d75...
# 2       Correction  nyt://article/0b55b248-0bfe-503d-8bcc-18f5d33a...
# 3            Quote  nyt://article/bccb0fd1-5bbe-5889-a2f6-36385173...
# 4             News  nyt://article/a82cb17f-3a34-544d-8f6d-66351480...
#
#    word_count                                                uri
# 0         964  nyt://article/09f1e20a-5d5b-5908-875b-830f45c7...
# 1         683  nyt://article/7e2ae77b-4d75-5b1b-9773-51f37d75...
# 2         440  nyt://article/0b55b248-0bfe-503d-8bcc-18f5d33a...
# 3          30  nyt://article/bccb0fd1-5bbe-5889-a2f6-36385173...
# 4         534  nyt://article/a82cb17f-3a34-544d-8f6d-66351480...

# %% [markdown]
# ### Deleting what I do not need.

# %%
# multimedia, byline won't be needed for my purposes (feel free to keep whatever data you want)
# uri and _id are the same so I will just keep the _id and put it in our first column
df.drop(['multimedia', 'byline', 'uri'], axis=1, inplace=True)

# %% [markdown]
# ### Reordering to make it more readable.

# %%
cols = list(df.columns)
print(cols)
# Out:
# ['abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section', 'print_page', 'source', 'headline', 'keywords', 'pub_date', 'document_type', 'news_desk', 'section_name', 'subsection_name', 'type_of_material', '_id', 'word_count']

# %%
# https://www.datasciencemadesimple.com/re-arrange-or-re-order-the-column-of-dataframe-in-pandas-python-2/ --> helpful article to reorder columns
columns_reordered = ['_id', 'abstract', 'web_url', 'snippet', 'lead_paragraph', 'print_section', 'print_page', 'source', 'pub_date', 'document_type',  'type_of_material', 'word_count','news_desk', 'section_name', 'subsection_name' , 'headline', 'keywords']
df2=df.reindex(columns= columns_reordered)
df2.head()
# Out:
#                                                  _id  \
# 0  nyt://article/09f1e20a-5d5b-5908-875b-830f45c7...
# 1  nyt://article/7e2ae77b-4d75-5b1b-9773-51f37d75...
# 2  nyt://article/0b55b248-0bfe-503d-8bcc-18f5d33a...
# 3  nyt://article/bccb0fd1-5bbe-5889-a2f6-36385173...
# 4  nyt://article/a82cb17f-3a34-544d-8f6d-66351480...
#
#                                             abstract  \
# 0  A senior administration official said the rock...
# 1  The 47-year-old man frequently swam into a lak...
# 2  Corrections that appeared in print on Wednesda...
# 3  Quotation of the Day for Wednesday, June 1, 2022.
# 4  A judge ruled that Ms. Palin failed to introdu...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2022/05/31/us/politics...
# 1  https://www.nytimes.com/2022/05/31/us/alligato...
# 2  https://www.nytimes.com/2022/05/31/pageoneplus...
# 3  https://www.nytimes.com/2022/05/31/todayspaper...
# 4  https://www.nytimes.com/2022/05/31/business/sa...
#
#                                              snippet  \
# 0  A senior administration official said the rock...
# 1  The 47-year-old man frequently swam into a lak...
# 2  Corrections that appeared in print on Wednesda...
# 3  Quotation of the Day for Wednesday, June 1, 2022.
# 4  A judge ruled that Ms. Palin failed to introdu...
#
#                                       lead_paragraph print_section print_page  \
# 0  WASHINGTON — The United States will send Ukrai...             A          9
# 1  The body of a man who had been retrieving Fris...           NaN        NaN
# 2  An article on Tuesday about a draft of an agre...             A         21
# 3  “It’s like saying to the world, ‘look, here we...             A          3
# 4  Sarah Palin lost her bid for a new trial in he...             B          4
#
#                source                  pub_date document_type  \
# 0  The New York Times  2022-06-01T00:05:37+0000       article
# 1  The New York Times  2022-06-01T00:42:23+0000       article
# 2  The New York Times  2022-06-01T00:54:49+0000       article
# 3  The New York Times  2022-06-01T00:55:52+0000       article
# 4  The New York Times  2022-06-01T01:14:09+0000       article
#
#   type_of_material  word_count    news_desk   section_name subsection_name  \
# 0             News         964   Washington           U.S.        Politics
# 1             News         683      Express           U.S.             NaN
# 2       Correction         440  Corrections    Corrections             NaN
# 3            Quote          30      Summary  Today’s Paper             NaN
# 4             News         534     Business   Business Day             NaN
#
#                                             headline  \
# 0  {'main': 'U.S. to Send Ukraine $700 Million in...
# 1  {'main': 'Alligator Kills Florida Man Retrievi...
# 2  {'main': 'Corrections: June 1, 2022', 'kicker'...
# 3  {'main': 'Quotation of the Day: Allinllachu, W...
# 4  {'main': 'Sarah Palin’s Bid for New Libel Tria...
#
#                                             keywords
# 0  [{'name': 'persons', 'value': 'Biden, Joseph R...
# 1  [{'name': 'subject', 'value': 'Alligators', 'r...
# 2                                                 []
# 3                                                 []
# 4  [{'name': 'subject', 'value': 'Libel and Sland...

# %% [markdown]
# ### Changing my datetime column to a date column.

# %%
# First turning the column into a datetime column
df2['pub_date'] = pd.to_datetime(df['pub_date'])
print(df2.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4374 entries, 0 to 4373
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   _id               4374 non-null   object
#  1   abstract          4374 non-null   object
#  2   web_url           4374 non-null   object
#  3   snippet           4374 non-null   object
#  4   lead_paragraph    4374 non-null   object
#  5   print_section     2359 non-null   object
#  6   print_page        2359 non-null   object
#  7   source            4374 non-null   object
#  8   pub_date          4374 non-null   datetime64[ns, UTC]
#  9   document_type     4374 non-null   object
#  10  type_of_material  4374 non-null   object
#  11  word_count        4374 non-null   int64
#  12  news_desk         4374 non-null   object
#  13  section_name      4374 non-null   object
#  14  subsection_name   2008 non-null   object
#  15  headline          4374 non-null   object
#  16  keywords          4374 non-null   object
# dtypes: datetime64[ns, UTC](1), int64(1), object(15)
# memory usage: 581.0+ KB
# None

# %%
# Changing my datetime column to a date column 
df2['pub_date'] = pd.to_datetime(df2['pub_date']).dt.date
df2.head()
# Out:
#                                                  _id  \
# 0  nyt://article/09f1e20a-5d5b-5908-875b-830f45c7...
# 1  nyt://article/7e2ae77b-4d75-5b1b-9773-51f37d75...
# 2  nyt://article/0b55b248-0bfe-503d-8bcc-18f5d33a...
# 3  nyt://article/bccb0fd1-5bbe-5889-a2f6-36385173...
# 4  nyt://article/a82cb17f-3a34-544d-8f6d-66351480...
#
#                                             abstract  \
# 0  A senior administration official said the rock...
# 1  The 47-year-old man frequently swam into a lak...
# 2  Corrections that appeared in print on Wednesda...
# 3  Quotation of the Day for Wednesday, June 1, 2022.
# 4  A judge ruled that Ms. Palin failed to introdu...
#
#                                              web_url  \
# 0  https://www.nytimes.com/2022/05/31/us/politics...
# 1  https://www.nytimes.com/2022/05/31/us/alligato...
# 2  https://www.nytimes.com/2022/05/31/pageoneplus...
# 3  https://www.nytimes.com/2022/05/31/todayspaper...
# 4  https://www.nytimes.com/2022/05/31/business/sa...
#
#                                              snippet  \
# 0  A senior administration official said the rock...
# 1  The 47-year-old man frequently swam into a lak...
# 2  Corrections that appeared in print on Wednesda...
# 3  Quotation of the Day for Wednesday, June 1, 2022.
# 4  A judge ruled that Ms. Palin failed to introdu...
#
#                                       lead_paragraph print_section print_page  \
# 0  WASHINGTON — The United States will send Ukrai...             A          9
# 1  The body of a man who had been retrieving Fris...           NaN        NaN
# 2  An article on Tuesday about a draft of an agre...             A         21
# 3  “It’s like saying to the world, ‘look, here we...             A          3
# 4  Sarah Palin lost her bid for a new trial in he...             B          4
#
#                source    pub_date document_type type_of_material  word_count  \
# 0  The New York Times  2022-06-01       article             News         964
# 1  The New York Times  2022-06-01       article             News         683
# 2  The New York Times  2022-06-01       article       Correction         440
# 3  The New York Times  2022-06-01       article            Quote          30
# 4  The New York Times  2022-06-01       article             News         534
#
#      news_desk   section_name subsection_name  \
# 0   Washington           U.S.        Politics
# 1      Express           U.S.             NaN
# 2  Corrections    Corrections             NaN
# 3      Summary  Today’s Paper             NaN
# 4     Business   Business Day             NaN
#
#                                             headline  \
# 0  {'main': 'U.S. to Send Ukraine $700 Million in...
# 1  {'main': 'Alligator Kills Florida Man Retrievi...
# 2  {'main': 'Corrections: June 1, 2022', 'kicker'...
# 3  {'main': 'Quotation of the Day: Allinllachu, W...
# 4  {'main': 'Sarah Palin’s Bid for New Libel Tria...
#
#                                             keywords
# 0  [{'name': 'persons', 'value': 'Biden, Joseph R...
# 1  [{'name': 'subject', 'value': 'Alligators', 'r...
# 2                                                 []
# 3                                                 []
# 4  [{'name': 'subject', 'value': 'Libel and Sland...

# %% [markdown]
# ### Checking for missing values
#
# I check for missing values to further understand my data. The next step will be to visualize my data to see what I am working with.

# %%
for column in df2.columns:
  print(f"{column} : {df2[column].isna().sum()}")
# Out:
# _id : 0
# abstract : 0
# web_url : 0
# snippet : 0
# lead_paragraph : 0
# print_section : 2015
# print_page : 2015
# source : 0
# pub_date : 0
# document_type : 0
# type_of_material : 0
# word_count : 0
# news_desk : 0
# section_name : 0
# subsection_name : 2366
# headline : 0
# keywords : 0

# %% [markdown]
# ## Time for some visualizations. 📊

# %% [markdown]
# ### Histograms to visualize the count of values within our columns
#
# Let's create some functions since we will be reusing them.

# %%
def plot_histogram_descending(df, x, color=None, color_discrete_sequence=None,labels={}, title=""):
  fig = px.histogram(df, x=x, text_auto=True, color=color, title=title, 
                   color_discrete_sequence=color_discrete_sequence, labels=labels)
  fig.update_layout(bargap=0.2)
  fig.update_xaxes(ticks="inside")
  fig.update_xaxes(categoryorder="total descending")
  fig.update_yaxes(ticks="inside", col=1)
  return fig.show()

# %%
def plot_histogram(df, x, color=None, color_discrete_sequence=None,labels={}, title=""):
  fig = px.histogram(df, x=x, text_auto=True, color=color, title=title, 
                   color_discrete_sequence=color_discrete_sequence, labels=labels)
  fig.update_layout(bargap=0.2)
  fig.update_xaxes(ticks="inside")
  fig.update_yaxes(ticks="inside", col=1)
  return fig.show()

# %%
plot_histogram(df2, x='pub_date', color='document_type', 
               labels=dict(pub_date="Date Published", document_type="Type of Document"),
               title="<b>Timeline of Articles Published in Month</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a0c30801-050d-4728-9d85-47379f996db5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a0c30801-050d-4728-9d85-47379f996db5")) {                    Plotly.newPlot(                        "a0c30801-050d-4728-9d85-47379f996db5",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Type of Document=article<br>Date Published=%{x}<br>count=%{y}<extra></extra>","legendgroup":"article","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"article","offsetgroup":"article","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-01","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02","2022-06-02"," ...

# %%
plot_histogram_descending(df2, x='type_of_material', color='type_of_material', 
               labels=dict(type_of_material="Material Type"),
               title="<b>Articles by Material Type</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="e43f9a13-015e-4b4d-84a9-ddb54247eb48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e43f9a13-015e-4b4d-84a9-ddb54247eb48")) {                    Plotly.newPlot(                        "e43f9a13-015e-4b4d-84a9-ddb54247eb48",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Material Type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"News","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"News","offsetgroup":"News","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News"," ...

# %%
plot_histogram_descending(df2, x='type_of_material', color='document_type',
                          color_discrete_sequence=['lightblue', 'green'],
                          labels=dict(type_of_material="Material Type"),
                          title="<b>Articles by Material Type</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="d17d3690-4897-4368-97cd-308e6ccf8068" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d17d3690-4897-4368-97cd-308e6ccf8068")) {                    Plotly.newPlot(                        "d17d3690-4897-4368-97cd-308e6ccf8068",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"document_type=article<br>Material Type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"article","marker":{"color":"lightblue","pattern":{"shape":""}},"name":"article","offsetgroup":"article","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["News","News","Correction","Quote","News","briefing","News","News","News","News","News","News","News","News","News","News","briefing","News","News","Op-Ed","Op-Ed","Op-Ed","Op-Ed","Op-Ed","News","Op-Ed","News","Op-Ed","News","Op-Ed","News","News","News","News","News","News","News","News","briefing","News","News","News","News","News","News","News","News","News","News","News","briefing","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","Review","News","News","News","News","News","News","News","News","Letter","News","Letter","News","News","News","News","Review","News","News","News","News","Op-Ed","Op-Ed","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","News","briefing","Review","News","News","News","Obituary (Obit)","News","Obituary (Obit)","News","News","News","News","News","News","News","News","Op-Ed","News","News","News","Op-Ed","News","News","News","Review","News Analysis","Review","Op-Ed","Op-Ed","News","Quote","News","News","News","News","News","briefing","briefing","News","News","News","News","News","News","News","News","News","News","News","Review","Op-Ed","News","News","News","News","News","Op-Ed","Op-Ed","Review","News","News","News","News","News","Op-Ed","News","Review","News","News","News","News","News","News","News","News","News","News","News","News","News","News","Op-Ed","Review","News","News","News","briefing","Review","Review","Review","Review","Review","Review","Review","Review","Review","Review","News","News","News","Review","briefing","Review","News","News","News","News","News","News","News","News","News","News","News","News","News","News","Review","News","News","News","News","Review","News","News","News","News","Review","News","News","News","News","News","News","Review","News","News","Op-Ed","News","News","News","News","News","Letter","News","News","News","News","News","News","News","News","News","News","News","Review","Op-Ed","Op-Ed","Review","News","News","News","News","News","News","Obituary (Obit)","News","News","News","News","News","News","News","News","News","News","News","briefing","News","News","News","News","News","News","News","News","briefing","Obituary (Obit)","Op-Ed","News","Review","Obituary (Obit)","News","Obituary (Obit)","Op-Ed","News","Op-Ed","News","News","News","News","News","News","News","News","News","Review","News","News","News","News","News","News","News","News","News","News","News","News","News","Review","briefing","Quote","Correction","News","News","News","News","briefing","List","Op-Ed","Op-Ed","Op-Ed","News","News","News","Op-Ed","Op-Ed","News","News","News","News","News","News","News","News","News","News","News","News","News","News","briefing","News","News","News","News","News","News","News","briefing","News","News","News","News","News","News","News","News","News","News","News","News","Letter","News","News","News","News","Review","News","News","News","Op-Ed","News","News","News","News","News","News","News","Review","News","News","News","News","News","News","News","News","Op-Ed","News","News","News ...

# %%
plot_histogram_descending(df2, x='news_desk', color='document_type', 
                              color_discrete_sequence=['coral', 'darkblue'],
                              labels=dict(news_desk="News Desk"),
                              title="<b>Articles Categorized by their News Desk</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="8ba468b6-e7a4-44fd-af60-5eceb3d12b3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ba468b6-e7a4-44fd-af60-5eceb3d12b3a")) {                    Plotly.newPlot(                        "8ba468b6-e7a4-44fd-af60-5eceb3d12b3a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"document_type=article<br>News Desk=%{x}<br>count=%{y}<extra></extra>","legendgroup":"article","marker":{"color":"coral","pattern":{"shape":""}},"name":"article","offsetgroup":"article","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Washington","Express","Corrections","Summary","Business","NYTNow","Culture","Sports","Sports","Sports","Foreign","Games","Insider","Metro","Business","Foreign","Metro","BookReview","Magazine","OpEd","OpEd","OpEd","OpEd","OpEd","Magazine","OpEd","Magazine","OpEd","Business","OpEd","Metro","RealEstate","Foreign","Arts&Leisure","RealEstate","Washington","Science","Podcasts","NYTNow","Sports","RealEstate","Business","Foreign","Weekend","RealEstate","Culture","Foreign","Washington","Business","Foreign","National","Foreign","Games","Culture","Business","Arts&Leisure","Express","Well","Games","Culture","Culture","Business","Business","Culture","Sports","Culture","Foreign","Sports","Metropolitan","Culture","Politics","Business","Washington","Business","Styles","Sports","Washington","Business","Letters","Culture","Dining","Foreign","Business","Culture","Culture","Culture","Travel","Foreign","Business","Foreign","OpEd","Editorial","Business","Climate","Business","Metro","Business","Weekend","Metro","Podcasts","Express","Styles","Business","Express","Metro","Investigative","Well","NYTNow","Styles","NYTNow","Weekend","Science","NYTNow","Climate","Obits","Express","Obits","Culture","Express","Sports","NYTNow","Metro","Foreign","Sports","Sports","OpEd","Politics","National","Culture","OpEd","Washington","Business","Washington","Weekend","Washington","Culture","OpEd","OpEd","Politics","Summary","Corrections","Washington","Games","Sports","Sports","NYTNow","Metro","Express","Foreign","Foreign","Foreign","Games","Summary","Washington","Science","Foreign","Foreign","Foreign","BookReview","OpEd","Learning","Well","Well","Weekend","RealEstate","OpEd","OpEd","BookReview","BookReview","SpecialSections","Business","Culture","SpecialSections","OpEd","National","Arts&Leisure","Metropolitan","Business","SpecialSections","Travel","Magazine","SpecialSections","Metro","SpecialSections","Foreign","SpecialSections","SpecialSections","SpecialSections","SpecialSections","SpecialSections","OpEd","Culture","Foreign","Podcasts","Podcasts","NYTNow","Weekend","Weekend","Weekend","Weekend","Weekend","Weekend","Weekend","Weekend","Weekend","Weekend","Express","Foreign","Foreign","Weekend","National","Weekend","Styles","Sports","Arts&Leisure","Business","TStyle","Business","RealEstate","RealEstate","Business","Culture","Business","National","Culture","Arts&Leisure","BookReview","Politics","Business","Arts&Leisure","Washington","Weekend","Culture","Weekend","Business","Metro","Weekend","Foreign","Weekend","Climate","Culture","Business","TStyle","Weekend","Sports","Dining","OpEd","Business","Foreign","Washington","Dining","Politics","Letters","Weekend","Weekend","Foreign","Metro","Foreign","Culture","National","Science","Washington","Foreign","Dining","Weekend","OpEd","OpEd","Weekend","Metro","Sports","Foreign","Foreign","Washington","Sports","Obits","Foreign","Politics","Books","Foreign","Washington","Sports","Culture","Washington","Styles","Foreign","Metro","NYTNow","NYTNow","Styles","Politics","Foreign","Business","Business","Business","Foreign","NYTNow","Obits","OpEd","Foreign","Culture","Obits","Culture","Obits","OpEd","Pol ...

# %%
plot_histogram_descending(df2, x='section_name', color='document_type',
                              color_discrete_sequence=['gold', 'gray'],
                              labels=dict(section_name="Section", document_type="Document Type"),
                              title="<b>Articles Categorized by Section</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="bf0a9e18-1b9e-445b-ad09-1f4a20ae80a6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bf0a9e18-1b9e-445b-ad09-1f4a20ae80a6")) {                    Plotly.newPlot(                        "bf0a9e18-1b9e-445b-ad09-1f4a20ae80a6",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Document Type=article<br>Section=%{x}<br>count=%{y}<extra></extra>","legendgroup":"article","marker":{"color":"gold","pattern":{"shape":""}},"name":"article","offsetgroup":"article","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["U.S.","U.S.","Corrections","Today\u2019s Paper","Business Day","Briefing","Arts","Sports","Sports","Sports","World","Crosswords & Games","Times Insider","New York","Technology","World","New York","Books","Magazine","Opinion","Opinion","Opinion","Opinion","Opinion","Magazine","Opinion","Magazine","Opinion","Your Money","Opinion","New York","Real Estate","World","Theater","Real Estate","U.S.","Health","Podcasts","Briefing","Sports","Real Estate","Technology","World","Arts","Real Estate","Arts","World","Business Day","Business Day","World","U.S.","World","Crosswords & Games","Arts","Technology","Arts","U.S.","Well","Crosswords & Games","Arts","Arts","Business Day","Business Day","Arts","Sports","Arts","World","Sports","New York","Theater","U.S.","Technology","U.S.","Business Day","Style","Sports","U.S.","Technology","Opinion","Arts","Food","World","Business Day","Arts","Arts","Books","Travel","World","Business Day","World","Opinion","Opinion","Business Day","Climate","Business Day","New York","Technology","Arts","New York","Podcasts","World","Style","Business Day","U.S.","New York","World","Well","Briefing","Style","Briefing","Movies","Health","Briefing","Climate","Arts","U.S.","U.S.","Arts","Arts","Sports","Briefing","New York","World","Sports","Sports","Opinion","U.S.","U.S.","Arts","Opinion","U.S.","Business Day","U.S.","Arts","U.S.","Theater","Opinion","Opinion","U.S.","Today\u2019s Paper","Corrections","U.S.","Crosswords & Games","Sports","Sports","Briefing","New York","U.S.","World","World","World","Crosswords & Games","Times Insider","U.S.","Health","World","World","World","Books","Opinion","The Learning Network","Well","Well","Books","Real Estate","Opinion","Opinion","Books","Books","Arts","Business Day","Arts","Arts","Opinion","U.S.","Movies","New York","Business Day","Arts","Travel","Magazine","Arts","New York","Real Estate","World","Arts","Arts","Arts","Real Estate","Arts","Opinion","Theater","World","Podcasts","Podcasts","Briefing","Movies","Movies","Movies","Movies","Movies","Movies","Movies","Movies","Movies","Movies","World","World","World","Movies","U.S.","Arts","Style","Sports","Arts","Business Day","T Magazine","Business Day","Real Estate","Real Estate","Business Day","Arts","Business Day","U.S.","Theater","Arts","Books","U.S.","Business Day","Arts","U.S.","Movies","Theater","Arts","Business Day","New York","Movies","World","Arts","Climate","Theater","Technology","T Magazine","Movies","Sports","Food","Opinion","Business Day","World","Business Day","Food","U.S.","Opinion","Arts","Arts","World","New York","World","Arts","U.S.","Science","U.S.","World","Food","Movies","Opinion","Opinion","Movies","New York","Sports","World","World","U.S.","Sports","Obituaries","World","U.S.","Books","World","U.S.","Sports","Movies","U.S.","Style","World","New York","Briefing","Briefing","Style","U.S.","World","Business Day","Business Day","Business Day","World","Briefing","Sports","Opinion","World","Theater","Arts","Arts","U.S.","Opinion","U.S.","Opinion","U.S.","Technology","New York","New York","U.S.","Sports","Arts","Well","Arts","Theater","Crosswords & Games","Crosswords & Games","U.S.","U. ...

# %%
plot_histogram_descending(df2, x='subsection_name', color='document_type',
                              color_discrete_sequence=['teal', 'lemonchiffon'],
                              labels=dict(subsection_name="Subsection", document_type="Document Type"),
                              title="<b>Articles Categorized by Subsection</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="90f24842-aed2-47ec-ad10-66679155e1e9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90f24842-aed2-47ec-ad10-66679155e1e9")) {                    Plotly.newPlot(                        "90f24842-aed2-47ec-ad10-66679155e1e9",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Document Type=article<br>Subsection=%{x}<br>count=%{y}<extra></extra>","legendgroup":"article","marker":{"color":"teal","pattern":{"shape":""}},"name":"article","offsetgroup":"article","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["Politics",null,null,null,null,null,"Art & Design","Hockey","Golf","Golf","Europe",null,null,null,null,"Europe",null,"Book Review",null,null,null,null,null,null,null,"Opinion | Technology",null,null,null,null,null,null,"Asia Pacific",null,null,"Politics",null,"The Daily",null,"Baseball",null,null,"Europe","Music",null,"Music","Australia","Economy","DealBook","Asia Pacific",null,"Middle East",null,"Television","Personal Tech","Art & Design",null,null,null,null,"Television",null,"Economy",null,"Soccer",null,"Africa","Soccer",null,null,"Politics",null,"Politics",null,null,"Baseball","Politics",null,"Letters","Television",null,"Europe","Media",null,"Television",null,null,"Europe",null,"Europe",null,null,"Energy & Environment ",null,null,null,null,null,null,null,"Africa",null,null,null,null,"Europe","Eat",null,null,null,null,null,null,null,"Music","Politics","Politics","Television",null,"Tennis",null,null,"Asia Pacific","Soccer","Baseball",null,"Politics",null,null,null,"Politics",null,null,"Art & Design","Politics",null,null,null,"Politics",null,null,null,null,"Hockey","Pro Basketball",null,null,null,"Europe","Europe","Europe",null,null,"Politics",null,"Europe","Europe","Australia","Book Review",null,null,"Mind","Move",null,null,null,null,"Book Review","Book Review","Art & Design","Economy","Television","Art & Design",null,null,null,null,null,"Art & Design",null,null,"Art & Design",null,null,"Americas","Art & Design","Art & Design","Art & Design","Real Estate","Art & Design",null,null,"Europe",null,"The Daily",null,null,null,null,null,null,null,null,null,null,null,"Europe","Europe","Europe",null,null,"Art & Design",null,"Baseball","Dance",null,null,"Media",null,null,null,"Television","DealBook",null,null,"Music","Book Review","Politics",null,"Television","Politics",null,null,"Television","Economy",null,null,"Europe","Art & Design",null,null,null,null,null,"Tennis","Wine, Beer & Cocktails",null,null,"Europe","Economy",null,"Politics","Letters","Dance","Television","Europe",null,"Africa",null,null,null,"Politics","Americas","Wine, Beer & Cocktails",null,null,null,null,null,"Pro Basketball","Europe","Europe","Politics",null,null,"Europe","Politics","Book Review","Europe","Politics","Soccer",null,"Politics",null,"Europe",null,null,null,null,"Politics","Europe",null,"Economy",null,"Europe",null,"Pro Football",null,"Europe",null,null,null,null,null,"Politics",null,null,null,null,null,null,"Pro Basketball","Dance","Live",null,null,null,null,"Politics",null,null,"Pro Basketball","Australia",null,null,null,null,null,null,"Book Review",null,null,null,"Asia Pacific","Europe",null,null,null,"Book Review",null,null,null,"Television","Mind","Economy",null,null,"Politics",null,null,null,null,null,"Asia Pacific",null,null,null,"Europe","Economy","Europe","The Daily",null,null,null,null,"Europe","Pro Basketball","Europe","Americas",null,"Book Review","DealBook",null,null,null,null,"Europe",null,"Music","Television",null,"Middle East",null,null,null,null,null,"Music",null,"Music",null,null,null,null,null,null,"Politics","Europe","Australia","Music","Music","Tennis",null,null,"Tennis",null,"Politics","Politics ...
